# %% [markdown]
# <center> <img src="data:image/svg+xml;base64,..." style="width:8.5%"/></center>

# %% [markdown]
# <center><font size=5 face="Helvetica" color=#76B900><b>
# Questions and Answers for Chapter 02
# </b></font></center>

# %% [markdown]
# <center><font face="Helvetica" size=3><b>Ang Chen</b></font></center>
# <center><font face="Helvetica" size=3>November, 2025</font></center>
#
# ***

# %% [markdown]
# $\texttt{Q1}$. Can we run CUDA on our main processor's built-in Intel HD GPU?
# What about on discrete AMD Radeon GPU?

# %% [markdown]
# $\texttt{A1}$. No, CUDA only supports NVIDIA GPUs, not Intel HD or AMD Radeon.

# %% [markdown]
# <div style="border-top: 1px dashed #aaa;"></div>

# %% [markdown]
# $\texttt{Q2}$. Does this book use Python 2.7 or Python 3.7 for examples?

# %% [markdown]
# $\texttt{A2}$. Python 2.7

# %% [markdown]
# <div style="border-top: 1px dashed #aaa;"></div>

# %% [markdown]
# $\texttt{Q3}$. What program do we use in Windows to see what GPU hardware we have installed?

# %% [markdown]
# $\texttt{A3}$. Device Manager.

# %% [markdown]
# <div style="border-top: 1px dashed #aaa;"></div>

# %% [markdown]
# $\texttt{Q4}$. What command-line program do we use in Linux to see what GPU hardware we have installed?

# %% [markdown]
# $\texttt{A4}$. `lspci`

# %% [markdown]
# <div style="border-top: 1px dashed #aaa;"></div>

# %% [markdown]
# $\texttt{Q5}$. What is the command we use in Linux to determine how much memory our system has?

# %% [markdown]
# $\texttt{A5}$. `free`

# %% [markdown]
# <div style="border-top: 1px dashed #aaa;"></div>

# %% [markdown]
# $\texttt{Q6}$. If we don't want to alter our Linux system's APT repository, should we use the run or deb installer for CUDA?

# %% [markdown]
# $\texttt{A6}$. `run`
